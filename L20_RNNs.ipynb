# %% [markdown]
# ## RNN

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10)) # wave 1
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # + wave 2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5) # + noise
    return series[..., np.newaxis].astype(np.float32)

# %%
generate_time_series(3, 10).shape
# Out:
# (3, 10, 1)

# %%
generate_time_series(3, 10)
# Out:
# array([[[-0.5116528 ],
#         [ 0.36110646],
#         [ 0.2259081 ],
#         [-0.22087191],
#         [-0.39460936],
#         [ 0.71158606],
#         [-0.21449949],
#         [-0.29964674],
#         [ 0.06630538],
#         [ 0.42075822]],
#
#        [[ 0.5278261 ],
#         [-0.58856666],
#         [-0.05922228],
#         [ 0.37269202],
#         [ 0.08698143],
#         [-0.4548745 ],
#         [-0.11513216],
#         [ 0.6959437 ],
#         [-0.38774648],
#         [-0.24695887]],
#
#        [[ 0.5562431 ],
#         [-0.16123354],
#         [-0.39904395],
#         [ 0.5846377 ],
#         [-0.19034922],
#         [-0.37684095],
#         [ 0.44504613],
#         [-0.12501504],
#         [-0.2982106 ],
#         [ 0.34028423]]], dtype=float32)

# %%
n_steps = 50
series = generate_time_series(10000, n_steps + 1)
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %%
X_train.shape
# Out:
# (7000, 50, 1)

# %%
plt.plot(X_train[4])

# %% [markdown]
# # baseline to evaluate a RNN

# %%
y_pred = X_valid[:, -1]
print(y_pred)
np.mean(keras.losses.mean_squared_error(y_valid, y_pred))
# Out:
# [[-0.28473374]
#  [-0.3577082 ]
#  [-0.4347753 ]
#  ...
#  [ 0.44494247]
#  [ 0.18370599]
#  [-0.24688563]]
# 0.02022823

# %% [markdown]
# # compare against a fully connected net

# %%
model = keras.models.Sequential([
        keras.layers.Flatten(input_shape=[50, 1]),
        keras.layers.Dense(1)
])


model.compile(loss="mse", optimizer="adam")

history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))

mse_test = model.evaluate(X_test, y_test)

print(f"MSE on test set: {mse_test:.3f}")
# Out:
# Epoch 1/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.1733 - val_loss: 0.0632
# Epoch 2/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0411 - val_loss: 0.0253
# Epoch 3/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0202 - val_loss: 0.0156
# Epoch 4/20
# 219/219 [==============================] - 1s 2ms/step - loss: 0.0139 - val_loss: 0.0120
# Epoch 5/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0112 - val_loss: 0.0102
# Epoch 6/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0091
# Epoch 7/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0082
# Epoch 8/20
# 219/219 [==============================] - 1s 2ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 9/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0068
# Epoch 10/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 11/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0061 - val_loss: 0.0058
# Epoch 12/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0056 - val_loss: 0.0054
# Epoch 13/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0053 - val_loss: 0.0052
# Epoch 14/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 15/20
# 219/219 [==============================] - 1s 2ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 16/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 17/20
# 219/219 [==============================] - 1s 2ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 18/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 19/20
# 219/219 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 20/20
# 219/219 [==============================] - 1s 2ms/step - loss: 0.0041 - val_loss: 0.0041
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0044
# MSE on test set: 0.004

# %% [markdown]
# # A simple RNN
#
# It contains a single layer, with a single neuron. We do not need to specify the length of the input sequences (unlike in the previous fully connected model), since a recurrent neural network can process any number of time steps (this is why we set the first input dimension to None).

# %%
model = keras.models.Sequential([
      keras.layers.SimpleRNN(1, activation='tanh', return_sequences=False, input_shape=[None, 1])
])

model.compile(loss="mse", optimizer="adam")

history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))

mse_test = model.evaluate(X_test, y_test)

print(f"MSE on test set: {mse_test:.3f}")
# Out:
# Epoch 1/20
# 219/219 [==============================] - 3s 10ms/step - loss: 0.3934 - val_loss: 0.3667
# Epoch 2/20
# 219/219 [==============================] - 4s 19ms/step - loss: 0.3451 - val_loss: 0.3215
# Epoch 3/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.3005 - val_loss: 0.2786
# Epoch 4/20
# 219/219 [==============================] - 2s 8ms/step - loss: 0.2590 - val_loss: 0.2389
# Epoch 5/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.2210 - val_loss: 0.2032
# Epoch 6/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.1876 - val_loss: 0.1729
# Epoch 7/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.1602 - val_loss: 0.1487
# Epoch 8/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.1386 - val_loss: 0.1293
# Epoch 9/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.1213 - val_loss: 0.1135
# Epoch 10/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.1047 - val_loss: 0.0948
# Epoch 11/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0852 - val_loss: 0.0758
# Epoch 12/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0684 - val_loss: 0.0607
# Epoch 13/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0546 - val_loss: 0.0480
# Epoch 14/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0431 - val_loss: 0.0375
# Epoch 15/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0336 - val_loss: 0.0290
# Epoch 16/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0262 - val_loss: 0.0226
# Epoch 17/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0206 - val_loss: 0.0180
# Epoch 18/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0167 - val_loss: 0.0149
# Epoch 19/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0142 - val_loss: 0.0130
# Epoch 20/20
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0127 - val_loss: 0.0119
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0125
# MSE on test set: 0.012

# %% [markdown]
# # Deep RNN

# %%
model = keras.models.Sequential([
        keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
        keras.layers.SimpleRNN(20, return_sequences=True),
        keras.layers.SimpleRNN(1) # return_sequence=False (univariate time series)
])
model.summary()

model.compile(loss="mse", optimizer="adam")

history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))

mse_test = model.evaluate(X_test, y_test)

print(f"MSE on test set: {mse_test:.3f}")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, None, 20)          440
#
#  simple_rnn_2 (SimpleRNN)    (None, None, 20)          820
#
#  simple_rnn_3 (SimpleRNN)    (None, 1)                 22
#
# =================================================================
# Total params: 1282 (5.01 KB)
# Trainable params: 1282 (5.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 219/219 [==============================] - 11s 39ms/step - loss: 0.0171 - val_loss: 0.0045
# Epoch 2/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0042 - val_loss: 0.0037
# Epoch 3/20
# 219/219 [==============================] - 9s 40ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 4/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 5/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 6/20
# 219/219 [==============================] - 7s 31ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 7/20
# 219/219 [==============================] - 7s 32ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 8/20
# 219/219 [==============================] - 7s 34ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 9/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 10/20
# 219/219 [==============================] - 7s 34ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 11/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 12/20
# 219/219 [==============================] - 7s 34ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 13/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 14/20
# 219/219 [==============================] - 7s 34ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 15/20
# 219/219 [==============================] - 6s 29ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 16/20
# 219/219 [==============================] - 8s 34ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 17/20
# 219/219 [==============================] - 7s 30ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 18/20
# 219/219 [==============================] - 7s 33ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 19/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 20/20
# 219/219 [==============================] - 6s 30ms/step - loss: 0.0027 - val_loss: 0.0027
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0027
# MSE on test set: 0.003

# %% [markdown]
# ## If we want to use activations other than tanh then use a dense layer at the end

# %%
model = keras.models.Sequential([
        keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
        keras.layers.SimpleRNN(20, return_sequences=False),
        keras.layers.Dense(1) # dense layer
])
model.summary()

model.compile(loss="mse", optimizer="adam")

history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))

mse_test = model.evaluate(X_test, y_test)

print(f"MSE on test set: {mse_test:.3f}")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_4 (SimpleRNN)    (None, None, 20)          440
#
#  simple_rnn_5 (SimpleRNN)    (None, 20)                820
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 1281 (5.00 KB)
# Trainable params: 1281 (5.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 219/219 [==============================] - 8s 23ms/step - loss: 0.0589 - val_loss: 0.0108
# Epoch 2/20
# 219/219 [==============================] - 5s 25ms/step - loss: 0.0071 - val_loss: 0.0054
# Epoch 3/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0045 - val_loss: 0.0041
# Epoch 4/20
# 219/219 [==============================] - 6s 26ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 5/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 6/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 7/20
# 219/219 [==============================] - 6s 26ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 8/20
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 9/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 10/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 11/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0029 - val_loss: 0.0034
# Epoch 12/20
# 219/219 [==============================] - 6s 26ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 13/20
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 14/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 15/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 16/20
# 219/219 [==============================] - 5s 21ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 17/20
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 18/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 19/20
# 219/219 [==============================] - 4s 20ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 20/20
# 219/219 [==============================] - 6s 26ms/step - loss: 0.0028 - val_loss: 0.0029
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0030
# MSE on test set: 0.003

# %% [markdown]
# # Previous models predicted only the next time step
#
# We want to predict multiple timesteps in the future

# %% [markdown]
# #### we can circulate back our immediate prediction

# %%
series = generate_time_series(1, n_steps + 10)
X_new, Y_new = series[:, :n_steps], series[:, n_steps:]
X = X_new
for step_ahead in range(10):
        y_pred_one = model.predict(X[:, step_ahead:])[:, np.newaxis, :]
        X = np.concatenate([X, y_pred_one], axis=1)
Y_pred = X[:, n_steps:]
print(Y_pred)
# Out:
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# [[[0.08078158]
#   [0.18092689]
#   [0.21588717]
#   [0.20431425]
#   [0.20281403]
#   [0.23552386]
#   [0.26965296]
#   [0.35185662]
#   [0.42204493]
#   [0.47227827]]]

# %%
plt.plot(X_new[0],'b')
plt.plot(X[0],'r.')

# %% [markdown]
# # Using LSTM

# %%
model = keras.models.Sequential([
        keras.layers.LSTM(20, return_sequences=True, input_shape=[None, 1]),
        keras.layers.LSTM(20, return_sequences=False),
        keras.layers.Dense(1) # dense layer
])
model.summary()

model.compile(loss="mse", optimizer="adam")

history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))

mse_test = model.evaluate(X_test, y_test)

print(f"MSE on test set: {mse_test:.3f}")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, None, 20)          1760
#
#  lstm_1 (LSTM)               (None, 20)                3280
#
#  dense_2 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 5061 (19.77 KB)
# Trainable params: 5061 (19.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 219/219 [==============================] - 14s 46ms/step - loss: 0.0517 - val_loss: 0.0228
# Epoch 2/20
# 219/219 [==============================] - 9s 42ms/step - loss: 0.0182 - val_loss: 0.0139
# Epoch 3/20
# 219/219 [==============================] - 8s 38ms/step - loss: 0.0112 - val_loss: 0.0076
# Epoch 4/20
# 219/219 [==============================] - 9s 41ms/step - loss: 0.0066 - val_loss: 0.0045
# Epoch 5/20
# 219/219 [==============================] - 9s 42ms/step - loss: 0.0042 - val_loss: 0.0034
# Epoch 6/20
# 219/219 [==============================] - 9s 41ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 7/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 8/20
# 219/219 [==============================] - 9s 42ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 9/20
# 219/219 [==============================] - 9s 42ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 10/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 11/20
# 219/219 [==============================] - 9s 42ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 12/20
# 219/219 [==============================] - 9s 41ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 13/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 14/20
# 219/219 [==============================] - 9s 41ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 15/20
# 219/219 [==============================] - 9s 41ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 16/20
# 219/219 [==============================] - 10s 46ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 17/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0026 - val_loss: 0.0035
# Epoch 18/20
# 219/219 [==============================] - 9s 41ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 19/20
# 219/219 [==============================] - 9s 41ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 20/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0026 - val_loss: 0.0026
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0027
# MSE on test set: 0.003

# %%
series = generate_time_series(1, n_steps + 10)
X_new, Y_new = series[:, :n_steps], series[:, n_steps:]
X = X_new
for step_ahead in range(10):
        y_pred_one = model.predict(X[:, step_ahead:])[:, np.newaxis, :]
        X = np.concatenate([X, y_pred_one], axis=1)
Y_pred = X[:, n_steps:]
print(Y_pred)
# Out:
# 1/1 [==============================] - 1s 772ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# [[[-0.16546936]
#   [-0.2838779 ]
#   [-0.35905588]
#   [-0.40081728]
#   [-0.42297474]
#   [-0.43374503]
#   [-0.43346035]
#   [-0.41644618]
#   [-0.37696236]
#   [-0.31542304]]]

# %%
plt.plot(X_new[0],'b')
plt.plot(X[0],'r.')
